# %%
import pandas as pd

df = pd.read_csv("data/e-commerce_stream/2019-Dec.csv")
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-12-01 00:00:00 UTC       view     1005105  2232732093077520756
# 1  2019-12-01 00:00:00 UTC       view    22700068  2232732091643068746
# 2  2019-12-01 00:00:01 UTC       view     2402273  2232732100769874463
# 3  2019-12-01 00:00:02 UTC   purchase    26400248  2053013553056579841
# 4  2019-12-01 00:00:02 UTC       view    20100164  2232732110089618156
#
#                    category_code  brand    price    user_id  \
# 0       construction.tools.light  apple  1302.48  556695836
# 1                            NaN  force   102.96  577702456
# 2   appliances.personal.massager  bosch   313.52  539453785
# 3  computers.peripherals.printer    NaN   132.31  535135317
# 4               apparel.trousers   nika   101.68  517987650
#
#                            user_session
# 0  ca5eefc5-11f9-450c-91ed-380285a0bc80
# 1  de33debe-c7bf-44e8-8a12-3bf8421f842a
# 2  5ee185a7-0689-4a33-923d-ba0130929a76
# 3  61792a26-672f-4e61-9832-7b63bb1714db
# 4  906c6ca8-ff5c-419a-bde9-967ba8e2233e

# %%
df.shape
# Out:
# (67542878, 9)

# %%
df.product_id.nunique()
# Out:
# 205230

# %%
df.category_id.nunique()
# Out:
# 1162

# %%
df.user_id.nunique()
# Out:
# 4577232

# %%
df.event_type.value_counts()
# Out:
# event_type
# view        62986067
# cart         3394763
# purchase     1162048
# Name: count, dtype: int64

# %%
res = df[['product_id', 'category_id', 'category_code', 'brand']]

# %%
res.to_csv("data/products_original.csv", index=False)

# %%
import pandas as pd

prod_orig = pd.read_csv("data/products_original.csv")
prod_orig.head()
# Out:
#    product_id          category_id                  category_code  brand
# 0     1005105  2232732093077520756       construction.tools.light  apple
# 1    22700068  2232732091643068746                            NaN  force
# 2     2402273  2232732100769874463   appliances.personal.massager  bosch
# 3    26400248  2053013553056579841  computers.peripherals.printer    NaN
# 4    20100164  2232732110089618156               apparel.trousers   nika

# %%
categories = prod_orig[['category_id', 'category_code']].drop_duplicates().reset_index(drop=True)

# %%
categories.head()
# Out:
#            category_id                  category_code
# 0  2232732093077520756       construction.tools.light
# 1  2232732091643068746                            NaN
# 2  2232732100769874463   appliances.personal.massager
# 3  2053013553056579841  computers.peripherals.printer
# 4  2232732110089618156               apparel.trousers

# %%
categories.shape
# Out:
# (1162, 2)

# %%
categories.to_csv("data/categories.csv", index=False)

# %%
import pandas as pd

cat_with_names = pd.read_csv("data/categories_with_names.csv")
cat_with_names.head()
# Out:
#            category_id                  category_code      category_name
# 0  2232732093077520756       construction.tools.light        work lights
# 1  2232732091643068746                            NaN  fishing equipment
# 2  2232732100769874463   appliances.personal.massager          massagers
# 3  2053013553056579841  computers.peripherals.printer           printers
# 4  2232732110089618156               apparel.trousers           trousers

# %%
prod_with_cat_names = prod_orig.join(
    cat_with_names.set_index('category_id')[['category_name']],
    on='category_id',
    how='left'
)
prod_with_cat_names.head()
# Out:
#    product_id          category_id                  category_code  brand  \
# 0     1005105  2232732093077520756       construction.tools.light  apple
# 1    22700068  2232732091643068746                            NaN  force
# 2     2402273  2232732100769874463   appliances.personal.massager  bosch
# 3    26400248  2053013553056579841  computers.peripherals.printer    NaN
# 4    20100164  2232732110089618156               apparel.trousers   nika
#
#        category_name
# 0        work lights
# 1  fishing equipment
# 2          massagers
# 3           printers
# 4           trousers

# %%
prods = prod_with_cat_names.drop_duplicates('product_id').sort_values('product_id').reset_index(drop=True)[['product_id','category_code', 'category_name']]
prods.head()
# Out:
#    product_id                     category_code  category_name
# 0     1000544            electronics.smartphone    smartphones
# 1     1000894            electronics.smartphone    smartphones
# 2     1000978  appliances.kitchen.refrigerators  refrigerators
# 3     1001588          construction.tools.light    work lights
# 4     1001605            electronics.smartphone    smartphones

# %%
prods.shape
# Out:
# (205230, 3)

# %%
prods.to_csv("data/products_with_category_names.csv", index=False)

# %%
prods_with_names = pd.read_csv("data/products_with_product_names.csv")
prods_with_names.head()
# Out:
#    product_id                     category_code  category_name  \
# 0     1000544            electronics.smartphone    smartphones
# 1     1000894            electronics.smartphone    smartphones
# 2     1000978  appliances.kitchen.refrigerators  refrigerators
# 3     1001588          construction.tools.light    work lights
# 4     1001605            electronics.smartphone    smartphones
#
#             product_name
# 0    smartphones Model 1
# 1    smartphones Model 2
# 2  refrigerators Model 3
# 3    work lights Model 4
# 4    smartphones Model 5

# %%
prod_with_prod_names = prod_with_cat_names.join(
    prods_with_names.set_index('product_id')[['product_name']],
    on='product_id',
    how='left'
)
prod_with_prod_names.head()
# Out:
#    product_id          category_id                  category_code  brand  \
# 0     1005105  2232732093077520756       construction.tools.light  apple
# 1    22700068  2232732091643068746                            NaN  force
# 2     2402273  2232732100769874463   appliances.personal.massager  bosch
# 3    26400248  2053013553056579841  computers.peripherals.printer    NaN
# 4    20100164  2232732110089618156               apparel.trousers   nika
#
#        category_name                    product_name
# 0        work lights          work lights Model 1178
# 1  fishing equipment  fishing equipment Model 101268
# 2          massagers            massagers Model 6303
# 3           printers           printers Model 125911
# 4           trousers            trousers Model 90435

# %%
prod_with_prod_names[['product_id', 'product_name', 'category_id', 'category_name', 'category_code', 'brand']].drop_duplicates('product_id').reset_index(drop=True).to_csv("data/products.csv", index=False)

# %%
products = pd.read_csv("data/products.csv")
products.head()
# Out:
#    product_id                    product_name          category_id  \
# 0     1005105          work lights Model 1178  2232732093077520756
# 1    22700068  fishing equipment Model 101268  2232732091643068746
# 2     2402273            massagers Model 6303  2232732100769874463
# 3    26400248           printers Model 125911  2053013553056579841
# 4    20100164            trousers Model 90435  2232732110089618156
#
#        category_name                  category_code  brand
# 0        work lights       construction.tools.light  apple
# 1  fishing equipment                            NaN  force
# 2          massagers   appliances.personal.massager  bosch
# 3           printers  computers.peripherals.printer    NaN
# 4           trousers               apparel.trousers   nika

# %%
users = pd.read_csv("data/users_original.csv")
users.head()
# Out:
#       Name    Surname  Birth Date  ID Number        PESEL             City  \
# 0     LENA  WITKOWSKA  1987-02-08  JZQ077116  87020827873            Oława
# 1  MARTYNA    WROŃSKA  1974-05-26  NZL415153  74052694410          Rzeszów
# 2    KINGA      DUDEK  1973-02-19  LVM049964  73021924671  Warszawa/Wesoła
# 3    PAWEŁ   SZYMCZAK  1999-06-30  LNM993793  99063054129         Warszawa
# 4    DAVYD      JANIK  1976-11-28  DYO250343  76112863288          Rzeszów
#
#   Postal Code                Street Name House Number
# 0      55-201         ul. E. Orzeszkowej       69/132
# 1      35-202  ul. Leona Staniszewskiego           68
# 2      05-075               ul. Malinowa           50
# 3      02-937             ul. Rumiankowa       31/149
# 4      35-111             ul. Poprzeczna           23

# %%
users_main = users[['Name', 'Surname', 'Birth Date', 'City', 'Postal Code', 'Street Name', 'House Number']].rename(columns={'Name': 'name', 'Surname': 'surname', 'Birth Date': 'birth_date', 'City': 'city', 'Postal Code': 'zip_code', 'Street Name': 'street_name', 'House Number': 'house_number'}, inplace=False)
users_main.head()
# Out:
#       name    surname  birth_date             city zip_code  \
# 0     LENA  WITKOWSKA  1987-02-08            Oława   55-201
# 1  MARTYNA    WROŃSKA  1974-05-26          Rzeszów   35-202
# 2    KINGA      DUDEK  1973-02-19  Warszawa/Wesoła   05-075
# 3    PAWEŁ   SZYMCZAK  1999-06-30         Warszawa   02-937
# 4    DAVYD      JANIK  1976-11-28          Rzeszów   35-111
#
#                  street_name house_number
# 0         ul. E. Orzeszkowej       69/132
# 1  ul. Leona Staniszewskiego           68
# 2               ul. Malinowa           50
# 3             ul. Rumiankowa       31/149
# 4             ul. Poprzeczna           23

# %%
user_ids = df['user_id'].unique()
user_ids.shape
# Out:
# (4577232,)

# %%
users_main['user_id'] = user_ids
users_main.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 users_main['user_id'] = user_ids
#       2 users_main.head()
#
# File c:\Users\flang\anaconda3\envs\data-science\Lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File c:\Users\flang\anaconda3\envs\data-science\Lib\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
#    4540         and not isinstance(value.dtype, ExtensionDtype)
#    4541     ):
#    4542         # broadcast across multiple columns if necessary
#    4543         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\flang\anaconda3\envs\data-science\Lib\site-packages\pandas\core\frame.py:5288, in DataFrame._sanitize_column(self, value)
#    5285     return _reindex_for_setitem(value, self.index)
#    5287 if is_list_like(value):
# -> 5288     com.require_length_match(value, self.index)
#    5289 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5290 if (
#    5291     isinstance(value, Index)
#    5292     and value.dtype == "object"
#    (...)   5295     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5296     # this deprecation
#
# File c:\Users\flang\anaconda3\envs\data-science\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (4577232) does not match length of index (1000000)
